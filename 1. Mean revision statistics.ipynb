# %%
L = [7,3,4,9,12,14,15]
sum_l = sum(L)
print("sum",sum_l)
count_l = len(L)
print("Count",count_l)
mean2= sum_l/count_l
print("mean is",mean2)
# Out:
# sum 64
# Count 7
# mean is 9.142857142857142

# %%
m = [14,42,17,19]
sum_m=sum(m)
print("sum",sum_m)
count=len(m)
print("count",count)
mean=sum_m/count
print("mean is",mean)
# Out:
# sum 92
# count 4
# mean is 23.0

# %%
p = [24,73,56,28,19,18,17,34,71]
sum_s= sum(p)
print("sum element",sum_s)
count=len(p)
print("count element",count)

mean=sum_s/count
print("mean is",mean)
# Out:
# sum element 340
# count element 9
# mean is 37.77777777777778

# %%
 Q = [24,19,18,17,34,71]
sum_list=sum(Q)
print("sum is",sum_list)
count = len(Q)
print("count",count)
mean=sum_list/count
print("mean is",mean)
# Out:
# sum is 183
# count 6
# mean is 30.5
