# %% [markdown]
# # Mode

# %%
data = [2,5,5,5,6,6,7]
freq = {} #Empty Dictionary
for x in data :
    freq[x] = freq.get(x,0)+1
    print(freq)
# Out:
# {2: 1}
# {2: 1, 5: 1}
# {2: 1, 5: 2}
# {2: 1, 5: 3}
# {2: 1, 5: 3, 6: 1}
# {2: 1, 5: 3, 6: 2}
# {2: 1, 5: 3, 6: 2, 7: 1}

# %%
max_freq = max(freq.values())
max_freq
# Out:
# 3

# %%
data = [2,5,5,5,6,6,7,7,7,7]
freq={}
for x in data:
    freq[x] = freq.get(x,0)+1
    print(freq)
# Out:
# {2: 1}
# {2: 1, 5: 1}
# {2: 1, 5: 2}
# {2: 1, 5: 3}
# {2: 1, 5: 3, 6: 1}
# {2: 1, 5: 3, 6: 2}
# {2: 1, 5: 3, 6: 2, 7: 1}
# {2: 1, 5: 3, 6: 2, 7: 2}
# {2: 1, 5: 3, 6: 2, 7: 3}
# {2: 1, 5: 3, 6: 2, 7: 4}

# %%
max_freq = max(freq.values())
max_freq
# Out:
# 4

# %%
data = [12,15,15,15,25,25,36,36,36,47,57,57]
freq={}
for x in data:
   freq[x]=freq.get(x,0)+1
   print(freq)
# Out:
# {12: 1}
# {12: 1, 15: 1}
# {12: 1, 15: 2}
# {12: 1, 15: 3}
# {12: 1, 15: 3, 25: 1}
# {12: 1, 15: 3, 25: 2}
# {12: 1, 15: 3, 25: 2, 36: 1}
# {12: 1, 15: 3, 25: 2, 36: 2}
# {12: 1, 15: 3, 25: 2, 36: 3}
# {12: 1, 15: 3, 25: 2, 36: 3, 47: 1}
# {12: 1, 15: 3, 25: 2, 36: 3, 47: 1, 57: 1}
# {12: 1, 15: 3, 25: 2, 36: 3, 47: 1, 57: 2}

# %%
max_freq=max(freq.values())
max_freq
# Out:
# 3

# %%
data=[1,2,2,3,3,4]
freq={}
for x in data:
    freq[x]=freq.get(x,0)+1
    print(freq)
# Out:
# {1: 1}
# {1: 1, 2: 1}
# {1: 1, 2: 2}
# {1: 1, 2: 2, 3: 1}
# {1: 1, 2: 2, 3: 2}
# {1: 1, 2: 2, 3: 2, 4: 1}

# %%
y = max(freq.values())
y
# Out:
# 2

# %%
data=[1,2,2,3,3,3,4,4,4,4]
freq={}
for x in data:
    freq[x]=freq.get(x,0)+1
    print(freq)
# Out:
# {1: 1}
# {1: 1, 2: 1}
# {1: 1, 2: 2}
# {1: 1, 2: 2, 3: 1}
# {1: 1, 2: 2, 3: 2}
# {1: 1, 2: 2, 3: 3}
# {1: 1, 2: 2, 3: 3, 4: 1}
# {1: 1, 2: 2, 3: 3, 4: 2}
# {1: 1, 2: 2, 3: 3, 4: 3}
# {1: 1, 2: 2, 3: 3, 4: 4}

# %%
y = max(freq.values())
y
# Out:
# 4
