# %% [markdown]
# # Median

# %%
# print position of list
L = [1,4,7,9,11]

print(L[0])
print(L[1])
print(L[2])
print(L[3])
print(L[4])
# Out:
# 1
# 4
# 7
# 9
# 11

# %%
#mid position(index) of length(odd number)
L = [1,4,7,9,11]
N = len(L)
mid_pos = N//2
print("index no",mid_pos)
# Out:
# index no 2

# %%
# mid value/median
L = [1,4,7,9,11]
N = len(L)
mid_pos = N//2
print("median is",L[mid_pos])
# Out:
# median is 7

# %%
# print position of list
k = [2,4,5,6,8,9,12,14,15,17,19]
print(k[0])
print(k[1])
print(k[2])
print(k[3])
print(k[4])
print(k[5])
print(k[6])
print(k[7])
print(k[8])
print(k[9])
print(k[10])
# Out:
# 2
# 4
# 5
# 6
# 8
# 9
# 12
# 14
# 15
# 17
# 19

# %%
# print mid position(odd number)
k = [2,4,5,6,8,9,12,14,15,17,19]
N = len(k)
print(N)
mid_pos=N//2
print(mid_pos)
# Out:
# 11
# 5

# %%
# print middle value / median (Odd number)
k = [2,4,5,6,8,9,12,14,15,17,19]
N = len(k)
mid_pos=N//2
print("median is",k[mid_pos])
# Out:
# median is 9

# %%
# print middle value / median 
m = [2,4,6,8]
print(m[0])
n = len(m)
print(n)
mid_pos = n//2,n//2-1
print(mid_pos)
# Out:
# 2
# 4
# (2, 1)

# %%
m = [2,4,6,8]
n = len(m)
median = (m[(n//2 - 1)])
med = (m[n//2])
print(med)
print(median)
f_median=(med+median)/2
print(f_median)
# Out:
# 6
# 4
# 5.0

# %%
# print middle value / median (Odd number)
k = [12,14,15,16,18,19,22,24,25,27,29,39,40,42,45,47,49]
n = len(k)
print(n)
print(k[0:18])
midpos = n//2
print("mid_pos",midpos)
print("median is",k[midpos])
# Out:
# 17
# [12, 14, 15, 16, 18, 19, 22, 24, 25, 27, 29, 39, 40, 42, 45, 47, 49]
# mid_pos 8
# median is 25

# %%
# print middle value / median (Odd number)
m = [12,14,15]
print(m[0:3])
p = len(m)
print(p)
midpos = p//2
print("mid_pos",midpos)
print("median is",m[midpos])
# Out:
# [12, 14, 15]
# 3
# mid_pos 1
# median is 14

# %%
# print middle value / median (Odd number)
N = [12,14,15,16,17]
print(N[0:])
n = len(N)
midpos = n//2
print("mid_pos",midpos)
print("median is",N[midpos])
# Out:
# [12, 14, 15, 16, 17]
# mid_pos 2
# median is 15

# %%
# print middle value / median (even number)
p = [12,14,15,16]
print(p[0:])
n = len(p)
midpos1,midpos2 = n//2 , n//2-1
print(midpos1,midpos2)
print("middle element is",p[midpos1],p[midpos2])
# Out:
# [12, 14, 15, 16]
# 2 1
# middle element is 15 14

# %%
# print middle value / median (even number)
q = [12,14,15,16,18,19]
print(q[0],q[1],q[2],q[3],q[4],q[5])
print(q[0:])
n = len(q)
midpos1,midpos2=n//2,n//2-1
print("middle index is",midpos1,midpos2)
print("middle element is",q[midpos1],q[midpos2])
# Out:
# 12 14 15 16 18 19
# [12, 14, 15, 16, 18, 19]
# middle index is 3 2
# middle element is 16 15

# %%
# print middle value / median (even number)
r = [12,14,15,16,18,19,20,22]
print(r[0:])
n = len(r)
midpos1 = n//2-1
midpos2 = n//2
print("midpos is",midpos1,midpos2)
print("middle element is",r[midpos1],r[midpos2])
# Out:
# [12, 14, 15, 16, 18, 19, 20, 22]
# midpos is 3 4
# middle element is 16 18

# %%
# print middle value / median (even number)
s = [12,14,15,16,18,19,20,22,24,27]
print(s[0:])
n = len(s)
midpos1 = n//2-1
midpos2 = n//2
print("middle index is",midpos1,midpos2)
print("middle element is",s[midpos1],s[midpos2])
# Out:
# [12, 14, 15, 16, 18, 19, 20, 22, 24, 27]
# middle index is 4 5
# middle element is 18 19

# %%
 t = [12, 14, 15, 16, 18, 19, 20, 22,24 ,27,36,78]
 n = len(t)
if n%2 == 0:
    midpos1=n//2-1
    midpos2=n//2
    print(midpos1,midpos2)
else:
    midpos=n//2
    print(midpos)
# Out:
# 5 6

# %%
 t = [12, 14, 15, 16, 18, 19, 20, 22,24 ,27,36,78]
 n = len(t)
if n%2 == 0:
    midpos1=n//2-1
    midpos2=n//2
    print(t[midpos1],t[midpos2])
else:
    midpos=n//2
    print(t[midpos])
# Out:
# 19 20

# %%
u = [12, 14, 15, 16, 18, 19, 20, 22,24 ,27,36,78,79,80,81]
print("total element is",u[0:])
n = len(u)
if n%2 == 0:
    midpos1=n//2-1
    midpos2=n//2
    print("middle index is",midpos1,midpos2)
    print("middle element is",u[midpos1],u[midpos2])
else:
    midpos=n//2
    print("middle index is",midpos)
    print("middle element is",u[midpos])
# Out:
# total element is [12, 14, 15, 16, 18, 19, 20, 22, 24, 27, 36, 78, 79, 80, 81]
# middle index is 7
# middle element is 22

# %%
 v = [12, 14, 15, 16, 18, 19, 20, 22,24 ,27,36,78,79,80,81,82,87,89,90,95,98]
print("total element is",v[0:])
n = len(v)
if n%2 == 0:
    midpos1=n//2-1
    midpos2=n//2
    print("middle index is",midpos1,midpos2)
    print("middle element is",v[midpos1],v[midpos2])
else:
    midpos=n//2
    print("middle index is",midpos)
    print("middle element is",v[midpos])
# Out:
# total element is [12, 14, 15, 16, 18, 19, 20, 22, 24, 27, 36, 78, 79, 80, 81, 82, 87, 89, 90, 95, 98]
# middle index is 10
# middle element is 36

# %%
      w = [2,4,5,6,8,9,10,22,24,27,36,48,59,80,81,82,87,89,90,95,98,109,110,110,111,116,118,119,227,228,229,230,235]
print("total element is",w[0:])
n=len(w)
if n%2 == 0:
    midpos1 = n//2-1
    midpos2 = n//2
    print("middle index is",midpos1,midpos2)
    print("middle element is",w[midpos1],w[midpos2])
else:
    midpos = n//2
    print("middle index is",midpos)
    print("middle element is",w[midpos])
# Out:
# total element is [2, 4, 5, 6, 8, 9, 10, 22, 24, 27, 36, 48, 59, 80, 81, 82, 87, 89, 90, 95, 98, 109, 110, 110, 111, 116, 118, 119, 227, 228, 229, 230, 235]
# middle index is 16
# middle element is 87

# %%
w = [2,4,5,6,8,9,10,22]
n = len(w)
if n%2 == 0:
    midpos1=n//2-1
    midpos2=n//2
    print("middle index is",midpos1,midpos2)
    print("middle element is",w[midpos1],w[midpos2])
    median = (w[midpos1]+w[midpos2])/2
    print(" median of data set w is",median)
else:
    midpos=n//2
    print("middle index is",midpos)
    print("middle element is",w[midpos])
    median=w[midpos]
    print("median of dataset w is",median)
# Out:
# middle index is 3 4
# middle element is 6 8
#  median of data set w is 7.0

# %%
w = [21,41,51,61,81,91,101,221]
n = len(w)
if n%2 == 0:
    midpos1 = n//2-1
    midpos2 = n//2
    print("middle index is",midpos1,midpos2)
    print("middle element is", w[midpos1],w[midpos2])
    median = (w[midpos1]+w[midpos2])/2
    print("median is",median)
else:
    midpos = n//2
    print("middle index is",midpos)
    print("middle element is",w[midpos])
    print("median is",w[midpos])
# Out:
# middle index is 3 4
# middle element is 61 81
# median is 71.0

# %%
v = [21,41,51,61,81,91,101,221,331,441,771,888]
n = len(v)
if n%2 == 0:
    midpos1 = n//2-1
    midpos2 = n//2
    print("middle index is",midpos1,midpos2)
    print("middle element is",v[midpos1],v[midpos2])
    median = (v[midpos1]+v[midpos2])/2
    print("median is",median)
else:
    midpos = n//2
    print("middle index is",midpos)
    print("middle element is",v[midpos])
    print("median is",v[midpos])
# Out:
# middle index is 5 6
# middle element is 91 101
# median is 96.0

# %%
w = [21,41,51,61,81,91,101,221]
n = len(w)
if n%2 == 0:
    midpos1 = n//2-1
    midpos2 = n//2
    median = (w[midpos1]+w[midpos2])/2
    print("median is",median)
else:
    midpos = n//2
    print("median is",w[midpos])
# Out:
# median is 71.0

# %%
 w = [21,41,61,51]
w.sort()
n = len(w)
if n%2 == 0:
    median = (w[n//2-1]+w[n//2])/2
    print("median is", median)
else:
    median = w[n//2]
    print("median is",median)
# Out:
# median is 46.0
